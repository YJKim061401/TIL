# %%
# !pip install pymysql

# %%
import pymysql

# %%
conn = pymysql.connect(host = 'localhost',port = 3306, user = 'root', passwd = '95Some2308!',db = 'classicmodels')
cur = conn.cursor()
cur

# %%
sql = 'SELECT * FROM customers'
cur.execute(sql)
# Out:
# 122

# %%
result = cur.fetchone()
print(result)
# Out:
# (103, 'Atelier graphique', 'Schmitt', 'Carine ', '40.32.2555', '54, rue Royale', None, 'Nantes', None, '44000', 'France', 1370, Decimal('21000.00'))

# %%
result = cur.fetchall()
print(result)
# Out:
# ((112, 'Signal Gift Stores', 'King', 'Jean', '7025551838', '8489 Strong St.', None, 'Las Vegas', 'NV', '83030', 'USA', 1166, Decimal('71800.00')), (114, 'Australian Collectors, Co.', 'Ferguson', 'Peter', '03 9520 4555', '636 St Kilda Road', 'Level 3', 'Melbourne', 'Victoria', '3004', 'Australia', 1611, Decimal('117300.00')), (119, 'La Rochelle Gifts', 'Labrune', 'Janine ', '40.67.8555', '67, rue des Cinquante Otages', None, 'Nantes', None, '44000', 'France', 1370, Decimal('118200.00')), (121, 'Baane Mini Imports', 'Bergulfsen', 'Jonas ', '07-98 9555', 'Erling Skakkes gate 78', None, 'Stavern', None, '4110', 'Norway', 1504, Decimal('81700.00')), (124, 'Mini Gifts Distributors Ltd.', 'Nelson', 'Susan', '4155551450', '5677 Strong St.', None, 'San Rafael', 'CA', '97562', 'USA', 1165, Decimal('210500.00')), (125, 'Havel & Zbyszek Co', 'Piestrzeniewicz', 'Zbyszek ', '(26) 642-7555', 'ul. Filtrowa 68', None, 'Warszawa', None, '01-012', 'Poland', None, Decimal('0.00')), (128, 'Blauer See Aut
# ...

# %%
for row in result:
    print(row[1:4])

# 작업이 끝났다면 db와의 연결 끊기 close()
# conn.commit() # insert,update,delete 등 DB 변경을 할 때 (깃허브 commit과 같음) 변경사항 업데이트 할 때 
conn.close() # DB 접속을 끝내기
# Out:
# ('Signal Gift Stores', 'King', 'Jean')
# ('Australian Collectors, Co.', 'Ferguson', 'Peter')
# ('La Rochelle Gifts', 'Labrune', 'Janine ')
# ('Baane Mini Imports', 'Bergulfsen', 'Jonas ')
# ('Mini Gifts Distributors Ltd.', 'Nelson', 'Susan')
# ('Havel & Zbyszek Co', 'Piestrzeniewicz', 'Zbyszek ')
# ('Blauer See Auto, Co.', 'Keitel', 'Roland')
# ('Mini Wheels Co.', 'Murphy', 'Julie')
# ('Land of Toys Inc.', 'Lee', 'Kwai')
# ('Euro+ Shopping Channel', 'Freyre', 'Diego ')
# ('Volvo Model Replicas, Co', 'Berglund', 'Christina ')
# ('Danish Wholesale Imports', 'Petersen', 'Jytte ')
# ('Saveley & Henriot, Co.', 'Saveley', 'Mary ')
# ('Dragon Souveniers, Ltd.', 'Natividad', 'Eric')
# ('Muscle Machine Inc', 'Young', 'Jeff')
# ('Diecast Classics Inc.', 'Leong', 'Kelvin')
# ('Technics Stores Inc.', 'Hashimoto', 'Juri')
# ('Handji Gifts& Co', 'Victorino', 'Wendy')
# ('Herkku Gifts', 'Oeztan', 'Veysel')
# ('American Souvenirs Inc', 'Franco', 'Keith')
# ...

# %%
# 새로운 쿼리문을 작성할 때마다 밑에 꺼 다시 해주어야함
# 요청이 완료되면 DB와의 연결을 끊음 (계속 접속중으로 나두면 과부화 걸림) 연결이 되고 끊어지고 이런 순환 

# 새로 DB연결
conn = pymysql.connect(host = 'localhost',port = 3306, user = 'root', passwd = '95Some2308!',db = 'classicmodels')
cur = conn.cursor()

num = 119

# list or tuple : %s / int 였으면 %d
sql = 'SELECT * FROM customers WHERE customerNumber = %s' # num이 들어갈 자리 
cur.execute(sql,(num)) #cursor.execute(sql) --> sql을 실행
print(sql)

result = cur.fetchone() # 결과 한개를 보여줌
print(result)

#result = cur.fetchall() # 모든 결과를 보여줌
#print(result)

print(result[0:4])

conn.close()
# Out:
# SELECT * FROM customers WHERE customerNumber = %s
# (119, 'La Rochelle Gifts', 'Labrune', 'Janine ', '40.67.8555', '67, rue des Cinquante Otages', None, 'Nantes', None, '44000', 'France', 1370, Decimal('118200.00'))
# (119, 'La Rochelle Gifts', 'Labrune', 'Janine ')

# %%
# 새로 DB연결
conn = pymysql.connect(host = 'localhost',port = 3306, user = 'root', passwd = '95Some2308!',db = 'classicmodels')
cur = conn.cursor()

search = 'A'
sql = 'SELECT * FROM customers WHERE customerName = %s'
cur.execute(sql,('La Rochelle Gifts'))
print(sql)

result = cur.fetchall() # 결과 한개를 보여줌
for row in result:
    print(result)
    
conn.close()
# Out:
# SELECT * FROM customers WHERE customerName = %s
# ((119, 'La Rochelle Gifts', 'Labrune', 'Janine ', '40.67.8555', '67, rue des Cinquante Otages', None, 'Nantes', None, '44000', 'France', 1370, Decimal('118200.00')),)

# %%
# 새로 DB연결
conn = pymysql.connect(host = 'localhost',port = 3306, user = 'root', passwd = '95Some2308!',db = 'classicmodels')
cur = conn.cursor()

search = 'a'                       # LIKE binary '%A%'
sql = 'SELECT * FROM customers WHERE customerName LIKE "%%%s%%"'
cur.execute(sql,(search))
print(sql)

result = cur.fetchall() # 결과 한개를 보여줌
for row in result:
    print(result)
    
#conn.close()
# Out:
# SELECT * FROM customers WHERE customerName LIKE "%%%s%%"

# %%
result = cur.fetchone() # 결과 한개를 보여줌
print(result)
# Out:
# None

# %%
# 새로 DB연결
conn = pymysql.connect(host = 'localhost',port = 3306, user = 'root', passwd = '95Some2308!',db = 'classicmodels')
cur = conn.cursor()

search = 'A'                       # LIKE binary '%A%'
sql = 'SELECT * FROM customers WHERE customerName LIKE binary "%%%s%%"' % (search)
cur.execute(sql)
print(sql)

result = cur.fetchall() # 결과 한개를 보여줌
for row in result:
    print(result)
    
conn.close()
# Out:
# SELECT * FROM customers WHERE customerName LIKE binary "%A%"
# ...

# %%
# 새로 DB연결
conn = pymysql.connect(host = 'localhost',port = 3306, user = 'root', passwd = '95Some2308!',db = 'classicmodels')
cur = conn.cursor()

search = 'mini'                       # LIKE binary '%A%' --> 대소문자 신경쓸거면 binary
sql = 'SELECT * FROM customers WHERE customerName LIKE %s'
cur.execute(sql, "%%%s%%" % (search))
print(sql)

result = cur.fetchall() # 결과 한개를 보여줌
for row in result:
    print(result)
    
conn.close()
# Out:
# SELECT * FROM customers WHERE customerName LIKE %s
# ...

# %% [markdown]
# * table : person
# * input을 이용해서 수정할 데이터를 입력 받아서 수행하는 프로그램을 구현하세요.
#
# * id, name

# %%
conn = pymysql.connect(host = 'localhost',port = 3306, user = 'root', passwd = '95Some2308!',db = 'shop')
cur = conn.cursor()

changed_name = input()

sql = 'UPDATE person SET name = %s WHERE id = 20'
cur.execute(sql, (changed_name))
# Out:
# 김이박
# ((10, '홍길동', 40), (20, '김이박', 30), (30, '고수', 20))

# %%
sql = 'SELECT * FROM person'
cur.execute(sql)
result = cur.fetchall()
#for row in result:
print(result)

conn.close()
# Out:
# ((10, '홍길동', 40), (20, '김이박', 30), (30, '고수', 20))
